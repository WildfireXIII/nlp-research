# %% [markdown]
# # Hierachical LDA (sort of)
#
# 1. Clustering in a graph by topic
# 2. Finding key words within a topic
#
# [Data source](https://www.kaggle.com/snapcrack/all-the-news#articles1.csv)
# [LDA Tutorial](https://medium.com/ml2vec/topic-modeling-is-an-unsupervised-learning-approach-to-clustering-documents-to-discover-topics-fdfbf30e27df)

# %%
import pandas as pd
dataset = pd.read_csv("data/articles1.csv")
dataset.head()
# Out:
#    Unnamed: 0     id                                              title  \
# 0           0  17283  House Republicans Fret About Winning Their Hea...
# 1           1  17284  Rift Between Officers and Residents as Killing...
# 2           2  17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3           3  17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4           4  17287  Kim Jong-un Says North Korea Is Preparing to T...
#
#       publication                         author        date    year  month  \
# 0  New York Times                     Carl Hulse  2016-12-31  2016.0   12.0
# 1  New York Times  Benjamin Mueller and Al Baker  2017-06-19  2017.0    6.0
# 2  New York Times                   Margalit Fox  2017-01-06  2017.0    1.0
# 3  New York Times               William McDonald  2017-04-10  2017.0    4.0
# 4  New York Times                  Choe Sang-Hun  2017-01-02  2017.0    1.0
#
#    url                                            content
# 0  NaN  WASHINGTON  —   Congressional Republicans have...
# 1  NaN  After the bullet shells get counted, the blood...
# 2  NaN  When Walt Disney’s “Bambi” opened in 1942, cri...
# 3  NaN  Death may be the great equalizer, but it isn’t...
# 4  NaN  SEOUL, South Korea  —   North Korea’s leader, ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import string

texts = list(dataset.content)
cleaned_texts = []

stopword_set = set(stopwords.words('english'))

stemmer = PorterStemmer()

for text in texts:
    clean = text.lower()
    
    # https://stackoverflow.com/questions/15547409/how-to-get-rid-of-punctuation-using-nltk-tokenizer
    translate_table = dict((ord(char), None) for char in string.punctuation)
    
    clean = clean.translate(translate_table)
    clean = nltk.word_tokenize(clean)
    clean = set(clean).difference(stopword_set)
    stemmed = []
    for token in clean:
        stemmed.append(stemmer.stem(token))
    cleaned_texts.append(stemmed)

# %%
from gensim.models import ldamodel
import gensim.corpora

num_topics = 10

id2word = gensim.corpora.Dictionary(cleaned_texts)

corpus = [id2word.doc2bow(text) for text in cleaned_texts]

lda = ldamodel.LdaModel(corpus=corpus, id2word=id2word, num_topics=num_topics)

# %%
def get_lda_topics(model, num_topics):
    word_dict = {};
    for i in range(num_topics):
        words = model.show_topic(i, topn = 20);
        word_dict['Topic # ' + '{:02d}'.format(i+1)] = [i[0] for i in words];
    return pd.DataFrame(word_dict);

# %%
get_lda_topics(lda, num_topics)
# Out:
#    Topic # 01 Topic # 02 Topic # 03 Topic # 04  Topic # 05 Topic # 06  \
# 0        year       kill          ”       look  republican      state
# 1           ’     attack          ’        day       trump     report
# 2           ”     report        say       time      donald     presid
# 3      accord          ’       show       work           ’          ”
# 4           1          ”       call        get    democrat          ’
# 5     increas      polic       time        one           ”     offici
# 6      report       said        one         go      presid   investig
# 7        said      offic       said          ’       elect     nation
# 8         000        one       like       like    campaign       said
# 9       state   investig       year       year        said       call
# 10     number     accord      peopl       home     support     govern
# 11    million      peopl       star          ”        vote        say
# 12       also        say       make       take  presidenti     includ
# 13          2        cnn         go       live         say      would
# 14     includ     arrest        get      first      candid       time
# 15       like       told       also      start       state        use
# 16          5        two        ask       make     clinton        law
# 17          3      state     follow     famili          go       issu
# 18       rate       citi       want        see       polit  administr
# 19     expect       call        cnn       love     hillari      secur
#
#    Topic # 07 Topic # 08 Topic # 09 Topic # 10
# 0        make       game    compani    countri
# 1        work       play          ’   european
# 2        like        win          ”     minist
# 3         use          ’       busi     leader
# 4        need       team          —      europ
# 5         way          ”        ceo     govern
# 6         get     player        new      prime
# 7       chang      sport       like       year
# 8        year       year        use     nation
# 9       thing      first       also          ’
# 10      think       time     report          ”
# 11       want      final       year    britain
# 12     differ     season       time      franc
# 13       help     second        one    british
# 14         go         go       said    germani
# 15       come        one      insid         uk
# 16       look      start     market      union
# 17       take        two       make      parti
# 18        one     athlet     includ      world
# 19        say      coach    million     london
